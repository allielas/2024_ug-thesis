# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
#from statannotations.Annotator import Annotator

# %%
#Import CSV
data = pd.read_csv('/Users/allielas/Desktop/MMU Lab/Presentations/aco2_testing_dataset.csv')

#Make it more readable
sns.set_context('notebook')

#Create a histogram
ax = sns.histplot(x='Compartment_label', data=data, hue='Compartment_label')

# Add plot labels
plt.xlabel('Phenotype')
plt.ylabel('Count')
plt.title('Heterogeneity of ACO2 Mutant Strains')

# Save and show the plot
plt.savefig("ACO2_heterogenetiy.png", format='png')
plt.show()

# %%
#Import data
data = pd.read_csv('/Users/allielas/Desktop/MMU Lab/Presentations/fixation_phenix_cp+stats.csv')

#Increase readability
sns.set_context('notebook')

# Create a bar graph with standard error for each group
ax = sns.barplot(x='Protocol', y='Mean_cell_Intensity_MeanIntensity_organelle_marker', 
                 data=data, errorbar='se', capsize=0.1 )

# Add plot labels
plt.xlabel('Protocol')
plt.ylabel('Mean Intensity')

#Assign Pairs
pairs=[("Ctrl", "1"), ("Ctrl", "4"), ("1", "4")]

#Set up annotations
annotator = Annotator(ax, pairs, data=data, 
                      x='Protocol', y='Mean_cell_Intensity_MeanIntensity_organelle_marker')
annotator.configure(test='t-test_ind', text_format='star', loc='inside')
annotator.apply_and_annotate()

#Save image and show plot
plt.savefig("fixation_intensity.png", format='png')
plt.show
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Ctrl vs. 1: t-test independent samples, P_val:1.066e-13 t=8.494e+00
# 1 vs. 4: t-test independent samples, P_val:6.918e-04 t=3.458e+00
# Ctrl vs. 4: t-test independent samples, P_val:2.286e-16 t=9.666e+00
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Example from annotator documentation
import seaborn as sns

from statannotations.Annotator import Annotator

df = sns.load_dataset("tips")
x = "day"
y = "total_bill"
order = ['Sun', 'Thur', 'Fri', 'Sat']

ax = sns.boxplot(data=df, x=x, y=y, order=order)

pairs=[("Thur", "Fri"), ("Thur", "Sat"), ("Fri", "Sun")]

annotator = Annotator(ax, pairs, data=df, x=x, y=y, order=order)
annotator.configure(test='Mann-Whitney', text_format='star', loc='inside')
annotator.apply_and_annotate()
# Out:
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Thur vs. Fri: Mann-Whitney-Wilcoxon test two-sided, P_val:6.477e-01 U_stat=6.305e+02
# Thur vs. Sat: Mann-Whitney-Wilcoxon test two-sided, P_val:4.690e-02 U_stat=2.180e+03
# Sun vs. Fri: Mann-Whitney-Wilcoxon test two-sided, P_val:2.680e-02 U_stat=9.605e+02
# (<Axes: xlabel='day', ylabel='total_bill'>,
# ...
#   <statannotations.Annotation.Annotation at 0x2809f6cd0>])
